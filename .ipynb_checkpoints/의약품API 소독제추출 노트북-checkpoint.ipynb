# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
#파싱후 출력 항목 추출 함수
def parse():
    try:
        ITEM_SEQ = item.find("ITEM_SEQ").get_text()
        ITEM_NAME = item.find("ITEM_NAME").get_text()
        ENTP_NAME = item.find("ENTP_NAME").get_text()
        ITEM_PERMIT_DATE = item.find("ITEM_PERMIT_DATE").get_text()
        INDUTY = item.find("INDUTY").get_text()
        PRDLST_STDR_CODE = item.find("PRDLST_STDR_CODE").get_text()
        SPCLTY_PBLC = item.find("SPCLTY_PBLC").get_text()
        PRDUCT_TYPE = item.find("PRDUCT_TYPE").get_text()
        PRDUCT_PRMISN_NO = item.find("PRDUCT_PRMISN_NO").get_text()
        ITEM_INGR_NAME = item.find("ITEM_INGR_NAME").get_text()
        ITEM_INGR_CNT = item.find("ITEM_INGR_CNT").get_text()
        PERMIT_KIND_CODE = item.find("PERMIT_KIND_CODE").get_text()
        CANCEL_DATE = item.find("CANCEL_DATE").get_text()
        CANCEL_NAME = item.find("CANCEL_NAME").get_text()
        BIG_PRDT_IMG_URL = item.find("BIG_PRDT_IMG_URL").get_text()
        ENTP_SEQ = item.find("ENTP_SEQ").get_text()
        ENTP_NO = item.find("ENTP_NO").get_text()
        EDI_CODE = item.find("EDI_CODE").get_text()
        return {
            "품목기준코드":ITEM_SEQ,
            "품목명":ITEM_NAME,
            "업체명":ENTP_NAME,
            "품목허가일자":ITEM_PERMIT_DATE,
            "업종":INDUTY,
            "품목일련번호":PRDLST_STDR_CODE,
            "전문/일반":SPCLTY_PBLC,
            "분류명":PRDUCT_TYPE,
            "품목허가번호":PRDUCT_PRMISN_NO,
            "주성분":ITEM_INGR_NAME,
            "주성분수":ITEM_INGR_CNT,
            "신고/허가":PERMIT_KIND_CODE,
            "취하일자":CANCEL_DATE,
            "취하구분":CANCEL_NAME,
            "이미지":BIG_PRDT_IMG_URL,
            "업일련번호": ENTP_SEQ,
            "업허가번호": ENTP_NO,
            "보험코드": EDI_CODE
        }
    except AttributeError as e:
        return {
            "품목기준코드":None,
            "품목명":None,
            "업체명":None,
            "품목허가일자":None,
            "업종":None,
            "품목일련번호":None,
            "전문/일반":None,
            "분류명":None,
            "품목허가번호":None,
            "주성분":None,
            "주성분수":None,
            "신고/허가":None,
            "취하일자":None,
            "취하구분":None,
            "이미지":None,
            "업일련번호":None,
            "업허가번호":None,
            "보험코드":None
        }

# %%
# 공공데이터 API 접속 url & 기본정보 파라미터
url = 'http://apis.data.go.kr/1471000/DrugPrdtPrmsnInfoService02/getDrugPrdtPrmsnInq02?'

# 공공데이터 service key
service_key = 'i4kidk21c3X/hLkySwIiPJ8aTr1xRqQ/CWnluHr1zG2jx1LUBZrsfheuojj5ZlO79XhfL0gAEfmrz3TqpVWidg=='

# %%
# 공공데이터 의약품 기본정보 파싱 함수
row = []

for n in range(600):
    params = {'serviceKey' : service_key, 
              'pageNo' : n+1, 
              'numOfRows' : '100'
               }
    r = requests.get(url, params)
    soup = BeautifulSoup(r.text, 'lxml-xml')
    items = soup.find_all("item")
    for item in items:
        row.append(parse())

# %%
df=pd.DataFrame(row)
print(df.shape)
df.head()
# Out:
# (48224, 18)
#       품목기준코드                                             품목명           업체명  \
# 0  195500002                                      종근당염산에페드린정        (주)종근당
# 1  195500005  중외5%포도당생리식염액(수출명:5%DextroseinnormalsalineInj.)  제이더블유중외제약(주)
# 2  195500006                                      중외5%포도당주사액  제이더블유중외제약(주)
# 3  195500014                                             영신단     엔비케이제약(주)
# 4  195600004                                     중외20%포도당주사액  제이더블유중외제약(주)
#
#      품목허가일자   업종     품목일련번호  전문/일반           분류명 품목허가번호  \
# 0  19550117  의약품  195500002  전문의약품  [02220]진해거담제      7
# 1  19550412  의약품  195500005  전문의약품  [03310]혈액대용제    792
# 2  19550413  의약품  195500006  전문의약품    [03230]당류제    192
# 3  19551008  의약품  195500014  일반의약품  [02330]건위소화제     37
# 4  19561129  의약품  195600004  전문의약품    [03230]당류제   5020
#
#                                   주성분 주성분수 신고/허가      취하일자    취하구분 이미지  \
# 0                              염산에페드린    1    허가  20200101  유효기간만료
# 1                           염화나트륨/포도당    2    신고                정상
# 2                                 포도당    1    신고                정상
# 3  감초/건강/고량강/박하/오매/옥수수전분/육계/정향/진피/향부자   10    신고  20200512      취하
# 4                                 포도당    1    신고                정상
#
#       업일련번호 업허가번호                                               보험코드
# 0  19650001  1459
# 1  19550004  1302                                644902212,644902220
# 2  19550004  1302  644902232,644902233,644902241,644902243,644902...
# 3  19550019  1309
# 4  19550004  1302                                644902021,644902042

# %%
df['분류명'].unique()
# Out:
# array(['[02220]진해거담제', '[03310]혈액대용제', '[03230]당류제', '[02330]건위소화제',
#        '[07130]용해제', '[02110]강심제', '[02650]기생성 피부질환용제', '[01240]진경제',
#        '[02370]정장제', '[02660]피부연화제(부식제를 포함)', '[02340]제산제',
#        '[06150]주로 그람양성, 음성균, 리케치아, 비루스에 작용하는 것', '[02130]이뇨제',
#        '[01410]항히스타민제', '[06130]주로 항산성균에 작용하는 것', '[06220]항결핵제',
#        '[03160]혼합비타민제(비타민AD 혼합제제를 제외)', '[02520]자궁수축제', '[01230]자율신경제',
#        '[02450]부신호르몬제', '[03290]기타의 자양강장변질제', '[03140]비타민 C 및 P제',
#        '[06410]항원충제', '[01150]각성제,흥분제', '[02640]진통.진양.수렴.소염제',
#        '[01140]해열.진통.소염제', '[04310]방사성 의약품', '[06160]주로 곰팡이, 원충에 작용하는 것',
#        '[03150]비타민 E 및 K제', '[02390]기타의 소화기관용약', '[02320]소화성궤양용제',
#        '[03120]비타민 B1제', '[06180]주로 그람양성, 음성균에 작용하는 것', '[03910]간장질환용제',
#        '[06210]설화제', '[03940]통풍치료제', '[03960]당뇨병용제', '[02350]최토제, 진토제',
#        '[01170]정신신경용제', '[01130]항전간제', '[06340]혈액제제류', '[03210]칼슘제',
#        '[01120]최면진정제', '[03920]해독제', '[06140]주로 그람양성균, 리케치아, 비루스에 작용하는 것',
#        '[03950]효소제제', '[01190]기타의 중추신경용약',
#        '[06190]기타의 항생물질제제(복합항생물질제제를 포함)', '[03130]비타민 B제(비타민 B1을 제외)',
#        '[03320]지혈제', '[03990]따로 분류되지 않는 대사성 의약품', '[04290]기타의 종양치료제',
#        '[01220]골격근이완제', '[02460]남성호르몬제', '[03190]기타의 비타민제', '[06420]구충제',
#        '[03330]혈액응고저지제', '[06110]주로 그람양성균에 작용하는 것', '[02380]하제, 완장제',
#        '[02190]기타의 순환계용약', '[01900]기타의 신경계및 감각기관용 의약품', '[02560]치질용제',
#        '[02530]통경제', '[02120]부정맥용제', '[02180]동맥경화용제', '[02630]화농성질환용제',
#        '[02590]기타의 비뇨생식기관 및 항문용약', '[02430]갑상선, 부갑상선호르몬제', '[08210]합성마약',
#        '[04900]기타의 조직세포의 기능용의약품', '[04210]항악성종양제',
#        '[02550]비뇨생식기관용제(성병예방제포함)', '[01210]국소마취제', '[02610]외피용살균소독제',
#        '[02310]치과구강용약', '[02290]기타의 호흡기관용약', '[06290]기타의 화학요법제',
#        '[03250]단백아미노산제제', '[01160]진훈제', '[07190]기타의 조제용약', '[01320]이비과용제',
#        '[02230]함소흡입제', '[04390]기타의 조직세포의 치료 및 진단', '[01110]전신마취제',
#        '[02170]혈관확장제', '[02140]혈압강하제', '[02900]기타의 개개의 기관용 의약품',
#        '[01310]안과용제', '[06120]주로 그람음성균에 작용하는 것', '[02210]호흡촉진제',
#        '[03390]기타의 혈액 및 체액용약', '[03490]기타의 인공관류용제', '[02150]혈관보강제',
#        '[02690]기타의 외피용약', '[01490]기타의 알레르기용약', '[02470]난포호르몬제 및 황체호르몬제',
#        '[02410]뇌하수체호르몬제', '[08110]아편알카로이드계 제제', '[03220]무기질제제',
#        '[01420]자격요법제(비특이성면역억제제를 포함)', '[06310]백신류', '[03260]장기제제',
#        '[06170]주로 악성종양에 작용하는 것', '[02360]이담제', '[06230]치나제',
#        '[07210]X선조영제', '[07320]방역용 살균소독제', '[02670]모발용제(발모, 탈모, 염모, 양모제)',
#        '[02490]기타의 호르몬제(항호르몬제를 포함)', '[03110]비타민 A 및 D제', '[07410]캅셀류',
#        '[02620]창상보호제', '[03410]인공신장관류용제', '[07280]기능 검사용 시약',
#        '[02160]혈관수축제', '[06330]항독소 및 렙토스피라혈청류', '[03980]종합대사성제제',
#        '[07290]기타의 진단용약', '[07990]따로 분류되지 않고 치료를 주목적으로 하지않는 의약품',
#        '[02440]단백동화스테로이드제', '[07390]기타의 공중위생용약', '[01250]발한제,지한제',
#        '[02540]피임제', '[06320]독소류 및 톡소이드류', '[07220]일반검사용 시약',
#        '[01390]기타의 감각기관용약', '[06390]기타의 생물학적 제제', '[01290]기타의 말초신경용약',
#        '[07250]면역혈청학적 검사용 시약', '[07240]생화화적 검사용 시약', '[03100]비타민제',
#        '[01100]중추신경계용약', '[02300]소화기관용약', '[02200]호흡기관용약',
#        '[06250]후란계 제제', '', '[01000]신경계 감각기관용 의약품', '[03900]기타의 대사성 의약품',
#        '[03200]자양강장변질제', '[06300]생물학적 제제', '[02600]외피용약',
#        '[47230]건위소화제(내용액제에 한함)', '[47210]저함량 비타민 및 미네랄 제제',
#        '[01200]말초신경계용약', '[06360]생물학적 제제'], dtype=object)

# %%
df[df['품목명']=='페라세이프(과붕산나트륨)']
# Out:
#          품목기준코드            품목명     업체명    품목허가일자              업종     품목일련번호  \
# 6947  199906930  페라세이프(과붕산나트륨)  (주)나노팜  19991001  의약품 및 의약외품 수입업  199906930
#
#       전문/일반               분류명 품목허가번호     주성분 주성분수 신고/허가 취하일자 취하구분 이미지  \
# 6947  일반의약품  [07320]방역용 살균소독제     16  과붕산나트륨    1    신고        정상
#
#          업일련번호 업허가번호 보험코드
# 6947  20162107   313

# %%
df.to_csv("medical_drugs.csv", mode="w")
