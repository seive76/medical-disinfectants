# %%
import tweepy
import classes.config

# %%
client = tweepy.Client(bearer_token=config.BEARER_TOKEN)

query = '소독제 -is:retweet'

# what if want to store them in txt

file_name = 'tweets_text.txt'

with open(file_name, 'a+') as filehandler:
    for tweet in tweepy.Paginator(client.search_recent_tweets, query = query, max_results=100).flatten(limit=1000):
        filehandler.write('%s\n' % tweet.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 client = tweepy.Client(bearer_token=config.BEARER_TOKEN)
#       3 query = '소독제 -is:retweet'
#       5 # what if want to store them in txt
#
# NameError: name 'config' is not defined

# %%
response = client.search_recent_tweets(query = query, 
                                       max_results=100,
                                       tweet_fields = ['created_at', 'lang'],
                                       user_fields=['profile_image_url'],
                                       expansions = ['author_id'])

users = {u['id']: u for u in response.includes['users']}

# %%
# Getting user information 

for tweet in response.data:
    if users[tweet.author_id]:
        user = users[tweet.author_id]
        print(tweet.id)
        print(user.username)
        print(user.profile_image_url)
# Out:
# 1580400593038094336
# zonnasaranghemz
# https://pbs.twimg.com/profile_images/1580228183554564101/UgpUpB89_normal.png
# 1580397278279258112
# jeongkiddo_1
# https://pbs.twimg.com/profile_images/1560853520953139200/R3aJAZWO_normal.jpg
# 1580392311334137857
# paydtpio
# https://pbs.twimg.com/profile_images/1568460682735255553/3Iz-Pyvy_normal.jpg
# 1580391341661376513
# the_secret_kbot
# https://pbs.twimg.com/profile_images/2997803893/db86ad082a207babaaa8cf1a41417b49_normal.jpeg
# 1580378901419020288
# MariaSm59801084
# https://pbs.twimg.com/profile_images/1580180665806774281/PrsdvQXw_normal.jpg
# 1580332585284415488
# HkU0AKpK6GU0hK4
# https://pbs.twimg.com/profile_images/1329411122684825600/uKJdO1rT_normal.jpg
# 1580317526700920832
# pFE4UvPJb5JVBns
# https://pbs.twimg.com/profile_images/1329284341113913344/ro4BjwQn_normal.jpg
# 1580263014447869953
# SherriO73902989
# https://pbs.twimg.com/profile_images/1580234677130244096/ZuNqt4BH_normal.jpg
# 1580259529442623488
# MariaSm59801084
# ...

# %%
# what if want to take out 1000

for tweet in tweepy.Paginator(client.search_recent_tweets, query = query, max_results=100).flatten(limit=1000):
    print(tweet.id)
# Out:
# 1580468323602796544
# 1580400593038094336
# 1580397278279258112
# 1580392311334137857
# 1580391341661376513
# 1580378901419020288
# 1580332585284415488
# 1580317526700920832
# 1580263014447869953
# 1580259529442623488
# 1580227382476431360
# 1580218147910533122
# 1580208160178307072
# 1580176875334545408
# 1580175589021220864
# 1580171991969320967
# 1580161979335192576
# 1580155120184352769
# 1580151428903239683
# 1580143808993378307
# 1580134744289087489
# 1580063113709498368
# 1580062028755922945
# 1580055550133690370
# 1580055203243782144
# 1580051290763145216
# 1579970245191553025
# 1579955093251960834
# 1579925355867312128
# 1579903154346684416
# 1579889701409824769
# 1579869548785782784
# 1579866366672531458
# 1579855584236818432
# 1579847862078550017
# 1579844318927654915
# 1579829363725729792
# 1579827132435292162
# 1579825670254780417
# 1579803848591699970
# 1579795840474173442
# 1579794727427538946
# 1579781417944641537
# 1579773987550162944
# 1579720911753969664
# ...

# %%
# what if we want to set start and end times between which tweets are treated
client2 = tweepy.Client(consumer_key=config.API_KEY, 
                        consumer_secret=config.API_SECRET, 
                        access_token=config.ACCESS_TOKEN, 
                        access_token_secret=config.ACCESS_TOKEN_SECRET)

start_time = '2022-06-01TOO:OO:OOZ'
end_time = '2022-10-01TOO:OO:OOZ'

response2 = client2.search_all_tweets(query=query, max_results=100, start_time = start_time, end_time = end_time)

for tweet in response2.data:
    print(tweet.id)
# Out:
# ---------------------------------------------------------------------------
# Unauthorized                              Traceback (most recent call last)
# Cell In [50], line 10
#       7 start_time = '2022-06-01TOO:OO:OOZ'
#       8 end_time = '2022-10-01TOO:OO:OOZ'
# ---> 10 response2 = client2.search_all_tweets(query=query, max_results=100, start_time = start_time, end_time = end_time)
#      12 for tweet in response2.data:
#      13     print(tweet.id)
#
# File ~/anaconda3/envs/twitter/lib/python3.9/site-packages/tweepy/client.py:1145, in Client.search_all_tweets(self, query, **params)
#    1053 """search_all_tweets( \
#    1054     query, *, end_time=None, expansions=None, max_results=None, \
#    1055     media_fields=None, next_token=None, place_fields=None, \
#    (...)
#    1142 .. _pagination: https://developer.twitter.com/en/docs/twitter-api/tweets/search/integrate/paginate
#    1143 """
#    1144 params["query"] = query
# -> 1145 return self._make_request(
# ...

# %%
query1 = '소독제 -is:retweet place_country:ko'
response1 = client.search_recent_tweets(query = query1, 
                                       max_results=100,
                                       tweet_fields = ['created_at', 'lang'],
                                       expansions = ['geo.place_id'])

places = {p['id']: p for p in response1.includes['places']}
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~/anaconda3/envs/twitter/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# ...
